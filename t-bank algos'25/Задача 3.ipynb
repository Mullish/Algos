# %% [markdown]
# ![Снимок экрана 2025-05-15 в 13.55.37.png](data:image/png;base64,...)![Снимок экрана 2025-05-15 в 13.55.47.png](data:image/png;base64,...)

# %%
def solve():
  n = int(input())
  a = list(map(int, input().split()))

  s = set()
  for x in a:
    while x > 0 and x in s:
      x //= 2
    s.add(x)

  if 0 in s and len([elem for elem in a if elem ==0])>1 :
        print(len(s) - 1)
  else:
        print(len(s))

solve()
# Out:
# 3
# 4 4 2
# 3
