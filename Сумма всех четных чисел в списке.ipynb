# %% [markdown]
# # Напишите функцию, которая возвращает сумму всех четных чисел в списке.

# %%
def sum_of_evens(numbers):
    return sum(num for num in numbers if num % 2 == 0)

# %%
# Пример использования
numbers = [1, 2, 3, 4, 5, 6]
print(sum_of_evens(numbers))  # Вывод: 12
# Out:
# 12
