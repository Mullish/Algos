# %% [markdown]
# # Фибоначчи (рекурсивно и итеративно). Напишите функции для вычисления n-го числа Фибоначчи как рекурсивно, так и итеративно.

# %%
def fibonacci_recursive(n):
    if n <= 0:
        return 0
    elif n == 1:
        return 1
    else:
        return fibonacci_recursive(n - 1) + fibonacci_recursive(n - 2)

# Пример использования
print(fibonacci_recursive(10))  # Вывод: 55
# Out:
# 55

# %%
def fibonacci_iterative(n):
    if n <= 0:
        return 0
    elif n == 1:
        return 1
    a, b = 0, 1
    for _ in range(2, n + 1):
        a, b = b, a + b
    return b

# Пример использования
print(fibonacci_iterative(10))  # Вывод: 55
# Out:
# 55
